# %%
import numpy as np
import matplotlib.pyplot as plt
L=5
p=0
Q=[]
pr=[]
perc_pr=[]
for gg in range(20):
    #print(p)
    perc_arr=[]
    number1_pr=[]
    for ss in range(100):
        mx=np.random.rand(L,L+2)
        color=np.zeros((L,L+2))
        #print(mx)
        for i in range(len(color)):
            for j in range(len(color[i])):
                if j==0 or j==L+1:
                    color[i][j]=1
        for i in range(len(mx)):
            for j in range(len(mx[i])):
                if j==0 or j==L+1:
                    mx[i][j]=1
                elif mx[i][j]<=p:
                    mx[i][j]=1
                else:
                    mx[i][j]=0
        #print(mx)
        k=1
        for j in range(1,L+1):
            for i in range(L):
                if i==0:
                    if mx[i][j]==1:
                        if mx[i][j-1]==1:
                            color[i][j]=color[i][j-1] 
                        else:
                            color[i][j]=k+1
                            k+=1
                    else:
                        continue
                else:
                    if mx[i][j]==1:
                        if mx[i][j-1]==1 and mx[i-1][j]==1:
                            color[i][j]=min(color[i][j-1],color[i-1][j])
                            for m in range(1,j+1):
                                for n in range(L):
                                    if color[n][m]==max(color[i][j-1],color[i-1][j]):
                                        color[n][m]=min(color[i][j-1],color[i-1][j])
                        elif mx[i][j-1]==1:
                            color[i][j]=color[i][j-1]
                        elif mx[i-1][j]==1:
                            color[i][j]=color[i-1][j]
                        else:
                            color[i][j]=k+1
                            k+=1
                    else:
                        continue
        #print("\n",color)
        for i in range(L):
            if color[i][L]==1:
                perc=1
                break
            else:
                perc=0
        #print("\n",perc)
        perc_arr.append(perc)
        number1=np.count_nonzero(color==1)-(2*L)
        #print("\n",number1)
        number1_pr.append(number1/(L**2))
        #print("\n",number1_pr)
    av_number1=sum(number1_pr)/len(number1_pr)
    Q.append(av_number1)
    print("\n",Q)
    av_perc=sum(perc_arr)/len(perc_arr)
    pr.append(p)
    perc_pr.append(av_perc)
    p+=0.05
    #print(perc_pr)

plt.plot(pr,Q,'bo')

L=10
p=0
Q=[]
pr=[]
perc_pr=[]
for gg in range(20):
    #print(p)
    perc_arr=[]
    number1_pr=[]
    for ss in range(100):
        mx=np.random.rand(L,L+2)
        color=np.zeros((L,L+2))
        #print(mx)
        for i in range(len(color)):
            for j in range(len(color[i])):
                if j==0 or j==L+1:
                    color[i][j]=1
        for i in range(len(mx)):
            for j in range(len(mx[i])):
                if j==0 or j==L+1:
                    mx[i][j]=1
                elif mx[i][j]<=p:
                    mx[i][j]=1
                else:
                    mx[i][j]=0
        #print(mx)
        k=1
        for j in range(1,L+1):
            for i in range(L):
                if i==0:
                    if mx[i][j]==1:
                        if mx[i][j-1]==1:
                            color[i][j]=color[i][j-1] 
                        else:
                            color[i][j]=k+1
                            k+=1
                    else:
                        continue
                else:
                    if mx[i][j]==1:
                        if mx[i][j-1]==1 and mx[i-1][j]==1:
                            color[i][j]=min(color[i][j-1],color[i-1][j])
                            for m in range(1,j+1):
                                for n in range(L):
                                    if color[n][m]==max(color[i][j-1],color[i-1][j]):
                                        color[n][m]=min(color[i][j-1],color[i-1][j])
                        elif mx[i][j-1]==1:
                            color[i][j]=color[i][j-1]
                        elif mx[i-1][j]==1:
                            color[i][j]=color[i-1][j]
                        else:
                            color[i][j]=k+1
                            k+=1
                    else:
                        continue
        #print("\n",color)
        for i in range(L):
            if color[i][L]==1:
                perc=1
                break
            else:
                perc=0
        #print("\n",perc)
        perc_arr.append(perc)
        number1=np.count_nonzero(color==1)-(2*L)
        #print("\n",number1)
        number1_pr.append(number1/(L**2))
        #print("\n",number1_pr)
    av_number1=sum(number1_pr)/len(number1_pr)
    Q.append(av_number1)
    print("\n",Q)
    av_perc=sum(perc_arr)/len(perc_arr)
    pr.append(p)
    perc_pr.append(av_perc)
    p+=0.05
    #print(perc_pr)

plt.plot(pr,Q,'go')

L=20
p=0
Q=[]
pr=[]
perc_pr=[]
for gg in range(20):
    #print(p)
    perc_arr=[]
    number1_pr=[]
    for ss in range(100):
        mx=np.random.rand(L,L+2)
        color=np.zeros((L,L+2))
        #print(mx)
        for i in range(len(color)):
            for j in range(len(color[i])):
                if j==0 or j==L+1:
                    color[i][j]=1
        for i in range(len(mx)):
            for j in range(len(mx[i])):
                if j==0 or j==L+1:
                    mx[i][j]=1
                elif mx[i][j]<=p:
                    mx[i][j]=1
                else:
                    mx[i][j]=0
        #print(mx)
        k=1
        for j in range(1,L+1):
            for i in range(L):
                if i==0:
                    if mx[i][j]==1:
                        if mx[i][j-1]==1:
                            color[i][j]=color[i][j-1] 
                        else:
                            color[i][j]=k+1
                            k+=1
                    else:
                        continue
                else:
                    if mx[i][j]==1:
                        if mx[i][j-1]==1 and mx[i-1][j]==1:
                            color[i][j]=min(color[i][j-1],color[i-1][j])
                            for m in range(1,j+1):
                                for n in range(L):
                                    if color[n][m]==max(color[i][j-1],color[i-1][j]):
                                        color[n][m]=min(color[i][j-1],color[i-1][j])
                        elif mx[i][j-1]==1:
                            color[i][j]=color[i][j-1]
                        elif mx[i-1][j]==1:
                            color[i][j]=color[i-1][j]
                        else:
                            color[i][j]=k+1
                            k+=1
                    else:
                        continue
        #print("\n",color)
        for i in range(L):
            if color[i][L]==1:
                perc=1
                break
            else:
                perc=0
        #print("\n",perc)
        perc_arr.append(perc)
        number1=np.count_nonzero(color==1)-(2*L)
        #print("\n",number1)
        number1_pr.append(number1/(L**2))
        #print("\n",number1_pr)
    av_number1=sum(number1_pr)/len(number1_pr)
    Q.append(av_number1)
    print("\n",Q)
    av_perc=sum(perc_arr)/len(perc_arr)
    pr.append(p)
    perc_pr.append(av_perc)
    p+=0.05
    #print(perc_pr)

plt.plot(pr,Q,'ro')


plt.show()
#plt.plot(pr,perc_pr,'bo')
#plt.show()
#plt.imshow(color, cmap='Set1_r')
#plt.show()
#plt.imshow(mx, cmap='viridis_r')
#plt.show()
# Out:
#  [0.0]
#
#  [0.0, 0.028717116217116208]
#
#  [0.0, 0.028717116217116208, 0.044928904428904445]
#
#  [0.0, 0.028717116217116208, 0.044928904428904445, 0.05621589439971793]
#
#  [0.0, 0.028717116217116208, 0.044928904428904445, 0.05621589439971793, 0.08948716080101528]
#
#  [0.0, 0.028717116217116208, 0.044928904428904445, 0.05621589439971793, 0.08948716080101528, 0.10522567868447188]
#
#  [0.0, 0.028717116217116208, 0.044928904428904445, 0.05621589439971793, 0.08948716080101528, 0.10522567868447188, 0.12842221559829914]
#
#  [0.0, 0.028717116217116208, 0.044928904428904445, 0.05621589439971793, 0.08948716080101528, 0.10522567868447188, 0.12842221559829914, 0.19620369587114092]
#
#  [0.0, 0.028717116217116208, 0.044928904428904445, 0.05621589439971793, 0.08948716080101528, 0.10522567868447188, 0.12842221559829914, 0.19620369587114092, 0.2352015242329348]
#
#  [0.0, 0.028717116217116208, 0.044928904428904445, 0.05621589439971793, 0.08948716080101528, 0.10522567868447188, 0.12842221559829914, 0.19620369587114092, 0.2352015242329348, 0.25180297005781593]
#
#  [0.0, 0.028717116217116208, 0.044928904428904445, 0.05621589439971793, 0.08948716080101528, 0.10522567868447188, 0.12842221559829914, 0.19620369587114092, 0.2352015242329348, 0.25180297005781593, 0.32823400110433903]
#
#  [0.0, 0.028717116217116208, 0.044928904428904445, 0.05621589439971793, 0.08948716080101528, 0.10522567868447188, 0.12842221559829914, 0.19620369587114092, 0.2352015242329348, 0.25180297005781593, 0.32823400110433903, 0.3481835474905723]
#
#  [0.0, 0.028717116217116208, 0.044928904428904445, 0.05621589439971793, 0.08948716080101528, 0.10522567868447188, 0.12842221559829914, 0.19620369587114092, 0.2352015242329348, 0.25180297005781593, 0.32823400110433903, 0.3481835474905723, 0.4346963641195274]
#
#  [0.0, 0.028717116217116208, 0.044928904428904445, 0.05621589439971793, 0.08948716080101528, 0.10522567868447188, 0.12842221559829914, 0.19620369587114092, 0.2352015242329348, 0.25180297005781593, 0.32823400110433903, 0.3481835474905723, 0.4346963641195274, 0.48780312136880544]
#
#  [0.0, 0.028717116217116208, 0.044928904428904445, 0.05621589439971793, 0.08948716080101528, 0.10522567868447188, 0.12842221559829914, 0.19620369587114092, 0.2352015242329348, 0.25180297005781593, 0.32823400110433903, 0.3481835474905723, 0.4346963641195274, 0.48780312136880544, 0.5862816632469143]
#
#  [0.0, 0.028717116217116208, 0.044928904428904445, 0.05621589439971793, 0.08948716080101528, 0.10522567868447188, 0.12842221559829914, 0.19620369587114092, 0.2352015242329348, 0.25180297005781593, 0.32823400110433903, 0.3481835474905723, 0.4346963641195274, 0.48780312136880544, 0.5862816632469143, 0.5897806039421585]
#
#  [0.0, 0.028717116217116208, 0.044928904428904445, 0.05621589439971793, 0.08948716080101528, 0.10522567868447188, 0.12842221559829914, 0.19620369587114092, 0.2352015242329348, 0.25180297005781593, 0.32823400110433903, 0.3481835474905723, 0.4346963641195274, 0.48780312136880544, 0.5862816632469143, 0.5897806039421585, 0.6371244737106069]
#
#  [0.0, 0.028717116217116208, 0.044928904428904445, 0.05621589439971793, 0.08948716080101528, 0.10522567868447188, 0.12842221559829914, 0.19620369587114092, 0.2352015242329348, 0.25180297005781593, 0.32823400110433903, 0.3481835474905723, 0.4346963641195274, 0.48780312136880544, 0.5862816632469143, 0.5897806039421585, 0.6371244737106069, 0.6698500074538442]
#
#  [0.0, 0.028717116217116208, 0.044928904428904445, 0.05621589439971793, 0.08948716080101528, 0.10522567868447188, 0.12842221559829914, 0.19620369587114092, 0.2352015242329348, 0.25180297005781

#
#  [0.0, 0.021861599416136464, 0.025070245743768583, 0.03596342242581421, 0.04437838388658923, 0.05662327701496166, 0.0630429278269949, 0.09215447233530166, 0.10623679629703736, 0.156025584094181, 0.20258103246117792, 0.312089172333724, 0.5453085176044824, 0.7183258358267943, 0.8279222114417891, 0.8667789087690001, 0.883881636077705, 0.892847478085785, 0.8994176559585084]
#
#  [0.0, 0.021861599416136464, 0.025070245743768583, 0.03596342242581421, 0.04437838388658923, 0.05662327701496166, 0.0630429278269949, 0.09215447233530166, 0.10623679629703736, 0.156025584094181, 0.20258103246117792, 0.312089172333724, 0.5453085176044824, 0.7183258358267943, 0.8279222114417891, 0.8667789087690001, 0.883881636077705, 0.892847478085785, 0.8994176559585084, 0.9047047739672819]

# %%
import numpy as np
import matplotlib.pyplot as plt
L=5
p=0
Q=[]
pr=[]
perc_pr=[]
for gg in range(20):
    #print(p)
    perc_arr=[]
    number1_pr=[]
    for ss in range(100):
        mx=np.random.rand(L,L+2)
        color=np.zeros((L,L+2))
        #print(mx)
        for i in range(len(color)):
            for j in range(len(color[i])):
                if j==0 or j==L+1:
                    color[i][j]=1
        for i in range(len(mx)):
            for j in range(len(mx[i])):
                if j==0 or j==L+1:
                    mx[i][j]=1
                elif mx[i][j]<=p:
                    mx[i][j]=1
                else:
                    mx[i][j]=0
        #print(mx)
        k=1
        for j in range(1,L+1):
            for i in range(L):
                if i==0:
                    if mx[i][j]==1:
                        if mx[i][j-1]==1:
                            color[i][j]=color[i][j-1] 
                        else:
                            color[i][j]=k+1
                            k+=1
                    else:
                        continue
                else:
                    if mx[i][j]==1:
                        if mx[i][j-1]==1 and mx[i-1][j]==1:
                            color[i][j]=min(color[i][j-1],color[i-1][j])
                            for m in range(1,j+1):
                                for n in range(L):
                                    if color[n][m]==max(color[i][j-1],color[i-1][j]):
                                        color[n][m]=min(color[i][j-1],color[i-1][j])
                        elif mx[i][j-1]==1:
                            color[i][j]=color[i][j-1]
                        elif mx[i-1][j]==1:
                            color[i][j]=color[i-1][j]
                        else:
                            color[i][j]=k+1
                            k+=1
                    else:
                        continue
        #print("\n",color)
        for i in range(L):
            if color[i][L]==1:
                perc=1
                break
            else:
                perc=0
        #print("\n",perc)
        perc_arr.append(perc)
        number1=np.count_nonzero(color==1)-(2*L)
        #print("\n",number1)
        non_zero=np.count_nonzero(color!=0)-(2*L)
        if non_zero==0:
            number1_pr.append(0)
        else:
            number1_pr.append(number1/non_zero)
        #print("\n",number1_pr)
    av_number1=sum(number1_pr)/len(number1_pr)
    Q.append(av_number1)
    print("\n",Q)
    av_perc=sum(perc_arr)/len(perc_arr)
    pr.append(p)
    perc_pr.append(av_perc)
    p+=0.05
    #print(perc_pr)

plt.plot(pr,Q,'yo')

L=10
p=0
Q=[]
pr=[]
perc_pr=[]
for gg in range(20):
    #print(p)
    perc_arr=[]
    number1_pr=[]
    for ss in range(100):
        mx=np.random.rand(L,L+2)
        color=np.zeros((L,L+2))
        #print(mx)
        for i in range(len(color)):
            for j in range(len(color[i])):
                if j==0 or j==L+1:
                    color[i][j]=1
        for i in range(len(mx)):
            for j in range(len(mx[i])):
                if j==0 or j==L+1:
                    mx[i][j]=1
                elif mx[i][j]<=p:
                    mx[i][j]=1
                else:
                    mx[i][j]=0
        #print(mx)
        k=1
        for j in range(1,L+1):
            for i in range(L):
                if i==0:
                    if mx[i][j]==1:
                        if mx[i][j-1]==1:
                            color[i][j]=color[i][j-1] 
                        else:
                            color[i][j]=k+1
                            k+=1
                    else:
                        continue
                else:
                    if mx[i][j]==1:
                        if mx[i][j-1]==1 and mx[i-1][j]==1:
                            color[i][j]=min(color[i][j-1],color[i-1][j])
                            for m in range(1,j+1):
                                for n in range(L):
                                    if color[n][m]==max(color[i][j-1],color[i-1][j]):
                                        color[n][m]=min(color[i][j-1],color[i-1][j])
                        elif mx[i][j-1]==1:
                            color[i][j]=color[i][j-1]
                        elif mx[i-1][j]==1:
                            color[i][j]=color[i-1][j]
                        else:
                            color[i][j]=k+1
                            k+=1
                    else:
                        continue
        #print("\n",color)
        for i in range(L):
            if color[i][L]==1:
                perc=1
                break
            else:
                perc=0
        #print("\n",perc)
        perc_arr.append(perc)
        number1=np.count_nonzero(color==1)-(2*L)
        #print("\n",number1)
        non_zero=np.count_nonzero(color!=0)-(2*L)
        if non_zero==0:
            number1_pr.append(0)
        else:
            number1_pr.append(number1/non_zero)
        #print("\n",number1_pr)
    av_number1=sum(number1_pr)/len(number1_pr)
    Q.append(av_number1)
    print("\n",Q)
    av_perc=sum(perc_arr)/len(perc_arr)
    pr.append(p)
    perc_pr.append(av_perc)
    p+=0.05
    #print(perc_pr)

plt.plot(pr,Q,'bo')

L=20
p=0
Q=[]
pr=[]
perc_pr=[]
for gg in range(20):
    #print(p)
    perc_arr=[]
    number1_pr=[]
    for ss in range(100):
        mx=np.random.rand(L,L+2)
        color=np.zeros((L,L+2))
        #print(mx)
        for i in range(len(color)):
            for j in range(len(color[i])):
                if j==0 or j==L+1:
                    color[i][j]=1
        for i in range(len(mx)):
            for j in range(len(mx[i])):
                if j==0 or j==L+1:
                    mx[i][j]=1
                elif mx[i][j]<=p:
                    mx[i][j]=1
                else:
                    mx[i][j]=0
        #print(mx)
        k=1
        for j in range(1,L+1):
            for i in range(L):
                if i==0:
                    if mx[i][j]==1:
                        if mx[i][j-1]==1:
                            color[i][j]=color[i][j-1] 
                        else:
                            color[i][j]=k+1
                            k+=1
                    else:
                        continue
                else:
                    if mx[i][j]==1:
                        if mx[i][j-1]==1 and mx[i-1][j]==1:
                            color[i][j]=min(color[i][j-1],color[i-1][j])
                            for m in range(1,j+1):
                                for n in range(L):
                                    if color[n][m]==max(color[i][j-1],color[i-1][j]):
                                        color[n][m]=min(color[i][j-1],color[i-1][j])
                        elif mx[i][j-1]==1:
                            color[i][j]=color[i][j-1]
                        elif mx[i-1][j]==1:
                            color[i][j]=color[i-1][j]
                        else:
                            color[i][j]=k+1
                            k+=1
                    else:
                        continue
        #print("\n",color)
        for i in range(L):
            if color[i][L]==1:
                perc=1
                break
            else:
                perc=0
        #print("\n",perc)
        perc_arr.append(perc)
        number1=np.count_nonzero(color==1)-(2*L)
        #print("\n",number1)
        non_zero=np.count_nonzero(color!=0)-(2*L)
        if non_zero==0:
            number1_pr.append(0)
        else:
            number1_pr.append(number1/non_zero)
        #print("\n",number1_pr)
    av_number1=sum(number1_pr)/len(number1_pr)
    Q.append(av_number1)
    print("\n",Q)
    av_perc=sum(perc_arr)/len(perc_arr)
    pr.append(p)
    perc_pr.append(av_perc)
    p+=0.05
    #print(perc_pr)

plt.plot(pr,Q,'go')

L=30
p=0
Q=[]
pr=[]
perc_pr=[]
for gg in range(20):
    #print(p)
    perc_arr=[]
    number1_pr=[]
    for ss in range(100):
        mx=np.random.rand(L,L+2)
        color=np.zeros((L,L+2))
        #print(mx)
        for i in range(len(color)):
            for j in range(len(color[i])):
                if j==0 or j==L+1:
                    color[i][j]=1
        for i in range(len(mx)):
            for j in range(len(mx[i])):
                if j==0 or j==L+1:
                    mx[i][j]=1
                elif mx[i][j]<=p:
                    mx[i][j]=1
                else:
                    mx[i][j]=0
        #print(mx)
        k=1
        for j in range(1,L+1):
            for i in range(L):
                if i==0:
                    if mx[i][j]==1:
                        if mx[i][j-1]==1:
                            color[i][j]=color[i][j-1] 
                        else:
                            color[i][j]=k+1
                            k+=1
                    else:
                        continue
                else:
                    if mx[i][j]==1:
                        if mx[i][j-1]==1 and mx[i-1][j]==1:
                            color[i][j]=min(color[i][j-1],color[i-1][j])
                            for m in range(1,j+1):
                                for n in range(L):
                                    if color[n][m]==max(color[i][j-1],color[i-1][j]):
                                        color[n][m]=min(color[i][j-1],color[i-1][j])
                        elif mx[i][j-1]==1:
                            color[i][j]=color[i][j-1]
                        elif mx[i-1][j]==1:
                            color[i][j]=color[i-1][j]
                        else:
                            color[i][j]=k+1
                            k+=1
                    else:
                        continue
        #print("\n",color)
        for i in range(L):
            if color[i][L]==1:
                perc=1
                break
            else:
                perc=0
        #print("\n",perc)
        perc_arr.append(perc)
        number1=np.count_nonzero(color==1)-(2*L)
        #print("\n",number1)
        non_zero=np.count_nonzero(color!=0)-(2*L)
        if non_zero==0:
            number1_pr.append(0)
        else:
            number1_pr.append(number1/non_zero)
        #print("\n",number1_pr)
    av_number1=sum(number1_pr)/len(number1_pr)
    Q.append(av_number1)
    print("\n",Q)
    av_perc=sum(perc_arr)/len(perc_arr)
    pr.append(p)
    perc_pr.append(av_perc)
    p+=0.05
    #print(perc_pr)

plt.plot(pr,Q,'ro')


plt.show()
#plt.plot(pr,perc_pr,'bo')
#plt.show()
#plt.imshow(color, cmap='Set1_r')
#plt.show()
#plt.imshow(mx, cmap='viridis_r')
#plt.show()
# Out:
#  [0.0]
#
#  [0.0, 0.165]
#
#  [0.0, 0.165, 0.21041666666666664]
#
#  [0.0, 0.165, 0.21041666666666664, 0.2389642857142857]
#
#  [0.0, 0.165, 0.21041666666666664, 0.2389642857142857, 0.2584300144300144]
#
#  [0.0, 0.165, 0.21041666666666664, 0.2389642857142857, 0.2584300144300144, 0.2820981795981795]
#
#  [0.0, 0.165, 0.21041666666666664, 0.2389642857142857, 0.2584300144300144, 0.2820981795981795, 0.31492649017649005]
#
#  [0.0, 0.165, 0.21041666666666664, 0.2389642857142857, 0.2584300144300144, 0.2820981795981795, 0.31492649017649005, 0.3665544178044177]
#
#  [0.0, 0.165, 0.21041666666666664, 0.2389642857142857, 0.2584300144300144, 0.2820981795981795, 0.31492649017649005, 0.3665544178044177, 0.3854199272949272]
#
#  [0.0, 0.165, 0.21041666666666664, 0.2389642857142857, 0.2584300144300144, 0.2820981795981795, 0.31492649017649005, 0.3665544178044177, 0.3854199272949272, 0.4348054723054724]
#
#  [0.0, 0.165, 0.21041666666666664, 0.2389642857142857, 0.2584300144300144, 0.2820981795981795, 0.31492649017649005, 0.3665544178044177, 0.3854199272949272, 0.4348054723054724, 0.5079858964564845]
#
#  [0.0, 0.165, 0.21041666666666664, 0.2389642857142857, 0.2584300144300144, 0.2820981795981795, 0.31492649017649005, 0.3665544178044177, 0.3854199272949272, 0.4348054723054724, 0.5079858964564845, 0.6504485865441747]
#
#  [0.0, 0.165, 0.21041666666666664, 0.2389642857142857, 0.2584300144300144, 0.2820981795981795, 0.31492649017649005, 0.3665544178044177, 0.3854199272949272, 0.4348054723054724, 0.5079858964564845, 0.6504485865441747, 0.7608121037888842]
#
#  [0.0, 0.165, 0.21041666666666664, 0.2389642857142857, 0.2584300144300144, 0.2820981795981795, 0.31492649017649005, 0.3665544178044177, 0.3854199272949272, 0.4348054723054724, 0.5079858964564845, 0.6504485865441747, 0.7608121037888842, 0.7929171616567126]
#
#  [0.0, 0.165, 0.21041666666666664, 0.2389642857142857, 0.2584300144300144, 0.2820981795981795, 0.31492649017649005, 0.3665544178044177, 0.3854199272949272, 0.4348054723054724, 0.5079858964564845, 0.6504485865441747, 0.7608121037888842, 0.7929171616567126, 0.884234563123495]
#
#  [0.0, 0.165, 0.21041666666666664, 0.2389642857142857, 0.2584300144300144, 0.2820981795981795, 0.31492649017649005, 0.3665544178044177, 0.3854199272949272, 0.4348054723054724, 0.5079858964564845, 0.6504485865441747, 0.7608121037888842, 0.7929171616567126, 0.884234563123495, 0.924457436483365]
#
#  [0.0, 0.165, 0.21041666666666664, 0.2389642857142857, 0.2584300144300144, 0.2820981795981795, 0.31492649017649005, 0.3665544178044177, 0.3854199272949272, 0.4348054723054724, 0.5079858964564845, 0.6504485865441747, 0.7608121037888842, 0.7929171616567126, 0.884234563123495, 0.924457436483365, 0.9461066000562901]
#
#  [0.0, 0.165, 0.21041666666666664, 0.2389642857142857, 0.2584300144300144, 0.2820981795981795, 0.31492649017649005, 0.3665544178044177, 0.3854199272949272, 0.4348054723054724, 0.5079858964564845, 0.6504485865441747, 0.7608121037888842, 0.7929171616567126, 0.884234563123495, 0.924457436483365, 0.9461066000562901, 0.9888970465379134]
#
#  [0.0, 0.165, 0.21041666666666664, 0.2389642857142857, 0.2584300144300144, 0.2820981795981795, 0.31492649017649005, 0.3665544178044177, 0.3854199272949272, 0.4348054723054724, 0.5079858964564845, 0.6504485865441747, 0.7608121037888842, 0.7929171616567126, 0.884234563123495, 0.924457436483365, 0.9461066000562901, 0.9888970465379134, 0.9953856164475359]
#
#  [0.0, 0.165, 0.21041666666666664, 0.2389642857142857, 0.2584300144300144, 0.2820981795981795, 0.31492649017649005, 0.3665544178044177, 0.3854199272949272, 0.4348054723054724, 0.5079858964564845, 0.6504485865441747, 0.7608121037888842, 0.7929171616567126, 0.884234563123495, 0.924457436483365, 0.9461066000562901, 0.9888970465379134, 0.9953856164475359, 0.9995238095238095]
#
#  [0.0]
#
#  [0.0, 0.08775793650793652]
#
#  [0.0, 0.08775793650793652, 0.08586474636474634]
#
#  [0.0, 0.08775793650793652, 0.08586474636474634, 0.10617818743863632]
#
#  [0.0, 0.08775793650793652, 0.08586474636474634, 0.10617818743863632, 0.13745830992568042]
#
#  [0.0, 0.08775793650793652, 0.08586474636474634, 0.10617818743863632, 0.13745830992568042, 0.13645781387166747]
#
#  [0.0, 0.08775793650793652, 0.08586474636474634, 0.10617818743863632, 0.13745830992568042, 0.13645781387166747, 0.17542864859755627]
#
#  [0.0, 0.08775793650793652, 0.08586474636474634, 0.10617818743863632, 0.13745830992568042, 0.13645781387166747, 0.17542864859755627, 0.2001205356551508]
#
#  [0.0, 0.08775793650793652, 0.08586474636474634, 0.10617818743863632, 0.13745830992568042, 0.13645781387166747, 0.17542864859755627, 0.2001205356551508, 0.22490441028997352]
#
#  [0.0, 0.08775793650793652, 0.08586474636474634, 0.10617818743863632, 0.13745830992568042, 0.13645781387166747, 0.17542864859755627, 0.2001205356551508, 0.22490441028997352, 0.3457924511273211]
#
#  [0.0, 0.08775793650793652, 0.08586474636474634, 0.10617818743863632, 0.13745830992568042, 0.13645781387166747, 0.17542864859755627, 0.2001205356551508, 0.22490441028997352, 0.3457924511273